# %%
# Bibliotecas necessárias para este script
suppressPackageStartupMessages(library('tidyverse'))
suppressPackageStartupMessages(library('tidylog'))

library('sf')
library('future.apply') # Aplicar funcoes em paralelo
library('data.table')   # manipulacao de dados

# Mostra valores sem notação científica
options(scipen=999)
`%nin%` = Negate(`%in%`)

options(repr.matrix.max.cols=50) # repr.matrix.max.rows=100
# Out:
# Linking to GEOS 3.9.1, GDAL 3.2.2, PROJ 8.0.0
#
# Loading required package: future
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
# Checando: Jupyter suporta multicore?
future::supportsMulticore()
# Out:
# [1] TRUE

# %%
# Do arquivo setup.R, vamos precisar desta parte
munis_list <- list(  
  munis_metro = tribble(
    ~abrev_muni, ~ano_metro,  ~code_muni,
#    "bel",       2017,     1501402,
    "bho",       2017,     3106200,
#    "bsb",       2017,     5300108,
    "cam",       2017,     3509502,
    "cgr",       2017,     5002704,
    "cur",       2017,     4106902,
#    "duq",       2017,     3301702,
    "for",       2017,     2304400,
    "goi",       2017,     5208707,
#    "gua",       2017,     3518800,
    "mac",       2017,     2704302,
    "man",       2017,     1302603,
    "nat",       2017,     2408102,
#    "poa",       2017,     4314902,
    "rec",       2017,     2611606,
    "rio",       2017,     3304557,
    "sal",       2017,     2927408,
#    "sgo",       2017,     3304904,
#    "slz",       2017,     2111300,
    "spo",       2017,     3550308,
# Novas cidades, ano base 2017
    "tsa",       2017,     2211001,
    "jpa",       2017,     2507507,
    "ula",       2017,     3170206,
    "vta",       2017,     3205309,
    "oco",       2017,     3534401,
    "sne",       2017,     3547809,
    "sjc",       2017,     3549904,
    "lda",       2017,     4113700,

#    "bel",       2018,     1501402,
    "bho",       2018,     3106200,
#    "bsb",       2018,     5300108,
    "cam",       2018,     3509502,
    "cgr",       2018,     5002704,
    "cur",       2018,     4106902,
#    "duq",       2018,     3301702,
    "for",       2018,     2304400,
    "goi",       2018,     5208707,
#    "gua",       2018,     3518800,
    "mac",       2018,     2704302,
    "man",       2018,     1302603,
    "nat",       2018,     2408102,
#    "poa",       2018,     4314902,
    "rec",       2018,     2611606,
    "rio",       2018,     3304557,
    "sal",       2018,     2927408,
#    "sgo",       2018,     3304904,
#    "slz",       2018,     2111300,
    "spo",       2018,     3550308,
# Novas cidades, ano base 2018
    "tsa",       2018,     2211001,
    "jpa",       2018,     2507507,
    "ula",       2018,     3170206,
    "vta",       2018,     3205309,
    "oco",       2018,     3534401,
    "sne",       2018,     3547809,
    "sjc",       2018,     3549904,
    "lda",       2018,     4113700,

#    "bel",       2019,     1501402,
    "bho",       2019,     3106200,
#    "bsb",       2019,     5300108,
    "cam",       2019,     3509502,
    "cgr",       2019,     5002704,
    "cur",       2019,     4106902,
#    "duq",       2019,     3301702,
    "for",       2019,     2304400,
    "goi",       2019,     5208707, #c(5208707,5200050,5201405,5201801,5203302,5203559,5203609,5204557,5205208,5208400,5208806,5209200,5209705,5214507,5215009,5219100,5219738,5220454,5221197,5221403),
#    "gua",       2019,     3518800,
    "mac",       2019,     2704302,
    "man",       2019,     1302603,
    "nat",       2019,     2408102,
#    "poa",       2019,     4314902,
    "rec",       2019,     2611606,
    "rio",       2019,     3304557,
    "sal",       2019,     2927408,
#    "sgo",       2019,     3304904,
#    "slz",       2019,     2111300,
    "spo",       2019,     3550308,
# Novas cidades, ano base 2019
    "tsa",       2019,     2211001,
    "jpa",       2019,     2507507,
    "ula",       2019,     3170206,
    "vta",       2019,     3205309,
    "oco",       2019,     3534401,
    "sne",       2019,     3547809,
    "sjc",       2019,     3549904,
    "lda",       2019,     4113700,

#    "bel",       2020,     1501402,
    "bho",       2020,     3106200,
#    "bsb",       2020,     5300108,
    "cam",       2020,     3509502,
    "cgr",       2020,     5002704,
    "cur",       2020,     4106902,
#    "duq",       2020,     3301702,
    "for",       2020,     2304400,
    "goi",       2020,     5208707, #c(5208707,5200050,5201405,5201801,5203302,5203559,5203609,5204557,5205208,5208400,5208806,5209200,5209705,5214507,5215009,5219100,5219738,5220454,5221197,5221403),
#    "gua",       2020,     3518800,
    "mac",       2020,     2704302,
    "man",       2020,     1302603,
    "nat",       2020,     2408102,
#    "poa",       2020,     4314902,
    "rec",       2020,     2611606,
    "rio",       2020,     3304557,
    "sal",       2020,     2927408,
#    "sgo",       2020,     3304904,
#    "slz",       2020,     2111300,
    "spo",       2020,     3550308,
# Novas cidades, ano base 2020
    "tsa",       2020,     2211001,
    "jpa",       2020,     2507507,
    "ula",       2020,     3170206,
    "vta",       2020,     3205309,
    "oco",       2020,     3534401,
    "sne",       2020,     3547809,
    "sjc",       2020,     3549904,
    "lda",       2020,     4113700,
  ) %>% setDT()
  
  
)

# %%
# Agregar informações dos setores censitários (renda, idade) para a grade estatística

# carregar bibliotecas
# source('fun/setup.R') # não vamos precisar do source no Jupyter

# ' A função 'renda_de_setor_p_grade()' passa todas as variáveis que foram coletadas
# ' dos setores censitários para as grades estatísticas  

renda_de_setor_p_grade <- function(ano, munis = "all") {
  
  renda_de_setor_p_grade_muni <- function(sigla_muni) {
    # sigla_muni <- 'oco'; ano <- 2019
    
    # Estrutura de pastas
    files_folder <- "../../indice-mobilidade_dados"
    subfolder3 <- sprintf("%s/03_grade_municipios/%s", files_folder, ano)
    subfolder4 <- sprintf("%s/04_setores_agregados/%s", files_folder, ano)
    subfolder13 <- sprintf("%s/13_grade_municipio_com_renda_cor/%s", files_folder, ano)
    dir.create(subfolder13, recursive = TRUE, showWarnings = FALSE)
    
    # status message
    message(Sys.time(), ' - Trabalhando na cidade: ', sigla_muni, '\n')
    
    # Checar se arquivo resultante já existe. Se sim, avisar e pular a cidade
    out_file <- sprintf("grade_renda_cor_%s_%s.rds", sigla_muni, ano)
    
    if (out_file %nin% list.files(subfolder13)){
      # Caminho para os arquivos
      path_setor <- sprintf("%s/setores_agregados_%s_%s.rds", subfolder4, sigla_muni, ano)
      path_grade <- sprintf("%s/grade_%s_%s.rds", subfolder3, sigla_muni, ano)
      
      # Ler shapes de setores censitários e grades estatísticas
      setor <- readr::read_rds(path_setor)
      grade <- readr::read_rds(path_grade)
      
      # Descartar grades vazias
      grade <- subset(grade, POP > 0)
      
      # Garantir que os dois shapes tenham a mesma projeção
      setor <- sf::st_transform(setor, sf::st_crs(grade))
      
      # Criar id unico de cada grade
      grade$id_grade <- 1:nrow(grade)
      
      # Corrigir grades de borda - cortar as grades da borda, tirar 
      # rebarbas e dividir a grade segundo recorte dos setores
      message('\n', Sys.time(), ' - 1-5: Começando cálculo de área geral em grade_corrigida em: ', sigla_muni, '\n')
      grade_corrigida <- 
        grade %>%
        # Deixar um registro da área de cada grade
        mutate(area_antes = as.numeric(st_area(.))) %>% 
        # Fazer interseção dos setores censitários com a grade - na prática,
        # atribui os ids da coluna code_tract para a grade
        st_intersection(setor %>% dplyr::select(code_tract))
      
      # Fazer o group_by() aqui vai dar um erro 'Assigned data `geom` must be 
      # compatible with existing data', dizendo que os dados existentes possuem
      # x linhas e os 'assigned data' possuem x+1 linhas. Vamos fazer esses
      # cálculos como um dataframe e depois o reassociaremos ao objeto 'grade_corrigida'
      grade_corrigida_df <-
        grade_corrigida %>% 
        as.data.frame() %>% 
        group_by(id_grade) %>%
        summarise(pop_total = first(POP),
                  pop_homens = first(MASC),
                  pop_mulheres = first(FEM),
                  area_antes = first(area_antes)) %>% 
        # Registrar proporção de homens e mulheres
        mutate(soma_pop_hm = pop_homens + pop_mulheres, 
               prop_homens = pop_homens / soma_pop_hm, 
               prop_mulheres = pop_mulheres / soma_pop_hm, 
               .before = 'area_antes') %>% 
        # Descartar coluna temporária pop_hm
        dplyr::select(-soma_pop_hm)
      
      # Substituir objeto 'grade_corrigida' com o resultado calculado em 
      # 'grade_corrigida_df' unido ao objeto 'grade' original
      rm(grade_corrigida)
      grade_corrigida <- grade %>% left_join(grade_corrigida_df, by = 'id_grade')
      
      # Corrigir população das grades de borda que foram cortadas porque parte 
      # da grade eventualmente cai fora do município
      grade_corrigida <- 
        grade_corrigida %>%    
        mutate(area_depois = as.numeric(st_area(.))) %>%
        mutate(prop = area_depois / area_antes) %>%
        mutate(pop_total = prop * pop_total,
               pop_homens = prop * pop_homens,
               pop_mulheres = prop * pop_mulheres)
      
      # Selecionar colunas da GRADE
      grade_corrigida <- 
        grade_corrigida %>%
        rename(area_grade = area_depois) %>%
        # pop_homens e pop_mulheres substituído aqui pelas colunas de proporções
        dplyr::select(id_grade, pop_total, prop_homens, prop_mulheres, area_grade) %>% 
        arrange(id_grade)
      
      
      
      # Criar id único de cada setor e filtrar colunas DO SETOR
      # calcula area de cada setor
      message('\n', Sys.time(), ' - 2-5: Começando cálculo de área geral em setor em : ', sigla_muni, '\n')
      setor <- 
        setor %>%
        mutate(id_setor = 1:n()) %>%
        mutate(area_setor = as.numeric(st_area(.))) %>%
        dplyr::select(id_setor, renda_total, area_setor, 
                      matches("moradores_SM"), # domicilios por renda
                      matches("cor_"), # cores
                      matches("idade")) # idade
      
      
      # agrega cor negra
      setDT(setor)[, cor_negra := cor_preta + cor_parda ]
      setor[, c('cor_preta', 'cor_parda') := NULL]
      
      # Calcular a proporção de cada cor em cada setor censitário - aqui, é 
      # calculada a proporção que cada segmento de população tem em relação à 
      # população dentro do próprio setor. A variável renda total não está aqui 
      # porque ela já representa o total da renda, não sendo segmentada
      setDT(setor)[,  pop_total := sum(cor_branca, cor_amarela, cor_indigena, cor_negra),  by=id_setor]
      setor[,  ":="(
        # renda
        moradores_SM_0_1Q = moradores_SM_0_1Q/pop_total,
        moradores_SM_1Q_1M = moradores_SM_1Q_1M/pop_total,
        moradores_SM_1M_1 = moradores_SM_1M_1/pop_total,
        moradores_SM_1_2 = moradores_SM_1_2/pop_total,
        moradores_SM_2 = moradores_SM_2/pop_total,
        
        # cor
        cor_b_prop = cor_branca/pop_total,
        cor_a_prop = cor_amarela/pop_total,
        cor_i_prop = cor_indigena/pop_total,
        cor_n_prop = cor_negra/pop_total,
        
        # idade
        idade_1_prop = idade_0a5/pop_total,
        idade_2_prop = idade_6a14/pop_total,
        idade_3_prop = idade_15a18/pop_total,
        idade_4_prop = idade_19a24/pop_total,
        idade_5_prop = idade_25a39/pop_total,
        idade_6_prop = idade_40a69/pop_total,
        idade_7_prop = idade_70/pop_total
      ), 
      
      by=id_setor]
      
      # volta para sf
      setor <- st_sf(setor)
      # head(setor, 3)
      
      
      # Função de reaportion com duas variáveis de referência (população e área);
      # resultado (ui_fim) é uma grade estatística com informação de renda 
      # inputada a partir do setor censitário
      
      ### aplicacao para renda --------------------------
      # tip from https://rpubs.com/rural_gis/255550
      message('\n', Sys.time(), ' - 3-5: Começando st_intersection() grade_corrigida vs setor em: ', sigla_muni, '\n')
      ui <- sf::st_intersection(grade_corrigida, setor)
      
      # O shape possui várias features com geometria inválida, transformá-las
      # antes de prosseguir
      message('\n', Sys.time(), ' - 4-5: Começando st_make_valid() em: ', sigla_muni, '\n')
      ui <- st_make_valid(ui)
      
      message('\n', Sys.time(), ' - 5-5: Começando cálculo de área do pedaço em: ', sigla_muni, '\n')
      ui <- ui %>%
        # Calcular a area de cada pedaco
        dplyr::mutate(area_pedaco = as.numeric(st_area(.))) %>%
        
        # Calcular a proporcao de cada setor que esta naquele pedaco (essa sera a area a ponderar pela renda)
        dplyr::mutate(area_prop_setor = area_pedaco/area_setor) %>%
        
        # Calcular a proporcao de cada grade que esta naquele pedacao
        dplyr::mutate(area_prop_grade =  area_pedaco/area_grade) %>%
        
        # Calcular a quantidade (absoluto) de populacao em cada pedaco (baseado na grade)
        dplyr::mutate(pop_sub_grade = pop_total * area_prop_grade) %>%
        
        # Calcular a populacao do setor somando-se a pop das grades
        # necessario pq populacao da grade nao bate 100% com po do setor
        group_by(id_setor) %>%
        dplyr::mutate(total_pop_setor = sum(pop_sub_grade, na.rm = TRUE)) %>%
        ungroup() %>%
        
        # Calcular a populacao proporcional de cada pedaco dentro do setor
        dplyr::mutate(pop_prop_grade_no_setor =  pop_sub_grade/total_pop_setor) %>%
        
        # Calcular a renda dentro de cada pedaco
        # assume que renda do setor eh distribuida igualmente para cada pessoa dentro do setor
        dplyr::mutate(renda_pedaco = renda_total * pop_prop_grade_no_setor) %>%
        # dplyr::mutate(moradores_SM_0_1Q_pedaco = moradores_SM_0_1Q * pop_prop_grade_no_setor) %>%
        # dplyr::mutate(moradores_SM_1Q_1M_pedaco = moradores_SM_1Q_1M * pop_prop_grade_no_setor) %>%
        # dplyr::mutate(moradores_SM_1M_1_pedaco = moradores_SM_1M_1 * pop_prop_grade_no_setor) %>%
        # dplyr::mutate(moradores_SM_1_2_pedaco = moradores_SM_1_2 * pop_prop_grade_no_setor) %>%
        # dplyr::mutate(moradores_SM_2_pedaco = moradores_SM_2 * pop_prop_grade_no_setor) %>%
        
        # Calcular cor/raca dentro de cada pedaco
        # como essas variaveis estao agora como proporcoes
        dplyr::mutate(branca_pedaco = cor_b_prop * pop_sub_grade) %>%
        dplyr::mutate(amarela_pedaco = cor_a_prop * pop_sub_grade) %>%
        dplyr::mutate(indigena_pedaco = cor_i_prop * pop_sub_grade) %>%
        dplyr::mutate(negra_pedaco = cor_n_prop * pop_sub_grade) %>%
        
        ## exemplo visual para entender o que esta sendo feito
        # subset(ui, id_grade %in% c(1306) ) %>% select(., id_grade, cor_b_prop, area_prop_grade, pop_total)
        
        # Calcular proporcionais para idade
        dplyr::mutate(idade_1_pedaco = idade_1_prop * pop_sub_grade) %>%
        dplyr::mutate(idade_2_pedaco = idade_2_prop * pop_sub_grade) %>%
        dplyr::mutate(idade_3_pedaco = idade_3_prop * pop_sub_grade) %>%
        dplyr::mutate(idade_4_pedaco = idade_4_prop * pop_sub_grade) %>%
        dplyr::mutate(idade_5_pedaco = idade_5_prop * pop_sub_grade) %>%
        dplyr::mutate(idade_6_pedaco = idade_6_prop * pop_sub_grade) %>%
        dplyr::mutate(idade_7_pedaco = idade_7_prop * pop_sub_grade)
      
      # # Grand Finale (uniao dos pedacos) - Agrupar por grade e somar a renda
      # ui_fim <- ui %>%
      #   st_set_geometry(NULL) %>%
      #   group_by(id_grade, pop_total, pop_homens, pop_mulheres) %>%
      #   dplyr::summarise(
      #     # renda
      #     renda = sum(renda_pedaco, na.rm = TRUE),
      #     # moradores_SM_0_1Q = sum(moradores_SM_0_1Q_pedaco, na.rm = TRUE),
      #     # moradores_SM_1Q_1M = sum(moradores_SM_1Q_1M_pedaco, na.rm = TRUE),
      #     # moradores_SM_1M_1 = sum(moradores_SM_1M_1_pedaco, na.rm = TRUE),
      #     # moradores_SM_1_2 = sum(moradores_SM_1_2_pedaco, na.rm = TRUE),
      #     # moradores_SM_2 = sum(moradores_SM_2_pedaco, na.rm = TRUE),
      #     # cor
      #     cor_branca = as.numeric(sum(branca_pedaco, na.rm = TRUE)),
      #     cor_amarela = as.numeric(sum(amarela_pedaco, na.rm = TRUE)),
      #     cor_indigena = as.numeric(sum(indigena_pedaco, na.rm = TRUE)),
      #     cor_negra = as.numeric(sum(negra_pedaco, na.rm = TRUE)),
      #     # para idade
      #     idade_0a5   = as.numeric(sum(idade_1_pedaco, na.rm = TRUE)),
      #     idade_6a14  = as.numeric(sum(idade_2_pedaco, na.rm = TRUE)),
      #     idade_15a18 = as.numeric(sum(idade_3_pedaco, na.rm = TRUE)),
      #     idade_19a24 = as.numeric(sum(idade_4_pedaco, na.rm = TRUE)),
      #     idade_25a39 = as.numeric(sum(idade_5_pedaco, na.rm = TRUE)),
      #     idade_40a69 = as.numeric(sum(idade_6_pedaco, na.rm = TRUE)),
      #     idade_70    = as.numeric(sum(idade_7_pedaco, na.rm = TRUE))
      #   ) %>%
      #   dplyr::mutate(renda = as.numeric(renda)) %>%
      #   ungroup()
      #    
      # ui_fim_sf <- grade_corrigida %>%
      #   dplyr::select(id_grade) %>%
      #   left_join(ui_fim, by = "id_grade") %>%
      #   # arredodandar valores
      #   mutate_at(vars(matches("pop|renda|moradores|cor|idade")), round)
      
      
      
      # Renomear as colunas 
      ui_fim_sf <- ui %>%
        mutate(pop_mulheres = pop_sub_grade * prop_mulheres,
               pop_homens   = pop_sub_grade * prop_homens,
               .after = 'pop_total') %>% 
        dplyr::select(
          id_grade, pop_total = pop_sub_grade, pop_mulheres, pop_homens,
          # renda
          renda = renda_pedaco,
          # moradores_SM_0_1Q = moradores_SM_0_1Q_pedaco,
          # moradores_SM_1Q_1M = moradores_SM_1Q_1M_pedaco,
          # moradores_SM_1M_1 = moradores_SM_1M_1_pedaco,
          # moradores_SM_1_2 = moradores_SM_1_2_pedaco,
          # moradores_SM_2 = moradores_SM_2_pedaco,
          
          # cor
          cor_branca = branca_pedaco,
          cor_amarela = amarela_pedaco,
          cor_indigena = indigena_pedaco,
          cor_negra = negra_pedaco,
          
          # para idade
          idade_0a5   = idade_1_pedaco,
          idade_6a14  = idade_2_pedaco,
          idade_15a18 = idade_3_pedaco,
          idade_19a24 = idade_4_pedaco,
          idade_25a39 = idade_5_pedaco,
          idade_40a69 = idade_6_pedaco,
          idade_70    = idade_7_pedaco
          )
        
      
      # Salvar em disco
      write_rds(ui_fim_sf, sprintf("%s/%s", subfolder13, out_file), compress = 'gz')
      message('\n', Sys.time(), ' - Finalizado: ', sigla_muni, '\n')
      
    } else {
      message('Arquivo para a cidade ', sigla_muni, " já existe, pulando...\n")
    }
    
  }
  
  #### Aplicando função em paralelo para salvar grades com info de renda
  if (munis == "all") {
    x = munis_list$munis_metro[ano_metro == ano]$abrev_muni
  } else (x = munis)
  
  # Parallel processing using future.apply
  if (future::supportsMulticore()) {
    future::plan(future::multicore)
  } else {
    future::plan(future::multisession)
  }
  invisible(future.apply::future_lapply(X = x, FUN=renda_de_setor_p_grade_muni, future.packages=c('sf', 'dplyr'), future.seed = TRUE))
#   lapply(X = x, FUN=renda_de_setor_p_grade_muni)
  
}


# Agregar informações dos setores censitários (renda, idade) para a grade 
# estatística - usar uma sigla das presentes em:
# munis_list$munis_metro[ano_metro == ano]$abrev_muni ou 'all' para todos
# renda_de_setor_p_grade(ano = 2019, munis = 'oco')
# renda_de_setor_p_grade(ano = 2019, munis = 'all')

# É importante mencionar que os processos de st_...() exigem bastante memória 
# RAM, em especial para estados grandes. Monitorar. Talvez seja preciso rodar
# por cidade e reiniciar a sessão como com .rs.restartR() após cada cidade

# renda_de_setor_p_grade(ano = 2019, munis = 'jpa')
# .rs.restartR()
# "bho" "cam" "cgr" "cur" "for" "goi" "mac" "man" "nat" "rec" "rio" "sal" "spo" 
# "tsa" "jpa" "ula" "vta" "oco" "sne" "sjc" "lda"

# %%
# Checando municípios para rodar
this <- munis_list$munis_metro[ano_metro == 2019]$abrev_muni
length(this)
this
# Out:
# [1] 21
#  [1] "bho" "cam" "cgr" "cur" "for" "goi" "mac" "man" "nat" "rec" "rio" "sal"
# [13] "spo" "tsa" "jpa" "ula" "vta" "oco" "sne" "sjc" "lda"

# %%
# Rodar tudo
renda_de_setor_p_grade(ano = 2019, munis = 'all')
# renda_de_setor_p_grade(ano = 2019, munis = 'oco')
# Out:
# 2021-12-08 10:35:16 - Trabalhando na cidade: bho
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: bho
#
#
# mutate: new variable 'area_antes' (double) with 6,848 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 6,821 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,022 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 3,873 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 3,873 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x      29
#
#            > rows only in y  (    0)
#
#            > matched rows     6,821
#
#            >                 =======
#
#            > rows total       6,850
#
# mutate: new variable 'area_depois' (double) with 6,848 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:26 - 2-5: Começando cálculo de área geral em setor em : bho
#
#
# mutate: new variable 'id_setor' (integer) with 3,936 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 3,936 unique values and 0% NA
#
#
# 2021-12-08 10:35:27 - 3-5: Começando st_intersection() grade_corrigida vs setor em: bho
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:35 - 4-5: Começando st_make_valid() em: bho
#
#
#
# 2021-12-08 10:35:39 - 5-5: Começando cálculo de área do pedaço em: bho
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 24,387 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 24,373 unique values and 0% NA
#
#
# 2021-12-08 10:35:41 - Finalizado: bho
#
#
# 2021-12-08 10:35:41 - Trabalhando na cidade: cam
#
#
#
# 2021-12-08 10:35:41 - 1-5: Começando cálculo de área geral em grade_corrigida em: cam
#
#
# mutate: new variable 'area_antes' (double) with 6,579 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 6,563 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 723 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 2,383 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 2,383 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x      21
#
#            > rows only in y  (    0)
#
#            > matched rows     6,563
#
#            >                 =======
#
#            > rows total       6,584
#
# mutate: new variable 'area_depois' (double) with 6,579 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:48 - 2-5: Começando cálculo de área geral em setor em : cam
#
#
# mutate: new variable 'id_setor' (integer) with 1,749 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,749 unique values and 0% NA
#
#
# 2021-12-08 10:35:49 - 3-5: Começando st_intersection() grade_corrigida vs setor em: cam
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:53 - 4-5: Começando st_make_valid() em: cam
#
#
#
# 2021-12-08 10:35:55 - 5-5: Começando cálculo de área do pedaço em: cam
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 15,518 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 15,526 unique values and 0% NA
#
#
# 2021-12-08 10:35:56 - Finalizado: cam
#
#
# 2021-12-08 10:35:56 - Trabalhando na cidade: cgr
#
#
#
# 2021-12-08 10:35:57 - 1-5: Começando cálculo de área geral em grade_corrigida em: cgr
#
#
# mutate: new variable 'area_antes' (double) with 6,537 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 6,532 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 484 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 2,012 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 2,012 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       5
#
#            > rows only in y  (    0)
#
#            > matched rows     6,532
#
#            >                 =======
#
#            > rows total       6,537
#
# mutate: new variable 'area_depois' (double) with 6,537 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:36:04 - 2-5: Começando cálculo de área geral em setor em : cgr
#
#
# mutate: new variable 'id_setor' (integer) with 1,063 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,063 unique values and 0% NA
#
#
# 2021-12-08 10:36:04 - 3-5: Começando st_intersection() grade_corrigida vs setor em: cgr
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:36:07 - 4-5: Começando st_make_valid() em: cgr
#
#
#
# 2021-12-08 10:36:08 - 5-5: Começando cálculo de área do pedaço em: cgr
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 12,780 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 12,851 unique values and 0% NA
#
#
# 2021-12-08 10:36:09 - Finalizado: cgr
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: cur
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: cur
#
#
# mutate: new variable 'area_antes' (double) with 8,813 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 8,796 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 828 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 3,229 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 3,229 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x      19
#
#            > rows only in y  (    0)
#
#            > matched rows     8,796
#
#            >                 =======
#
#            > rows total       8,815
#
# mutate: new variable 'area_depois' (double) with 8,813 unique values and 0% NA
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:26 - 2-5: Começando cálculo de área geral em setor em : cur
#
#
# mutate: new variable 'id_setor' (integer) with 2,395 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 2,395 unique values and 0% NA
#
#
# 2021-12-08 10:35:27 - 3-5: Começando st_intersection() grade_corrigida vs setor em: cur
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:34 - 4-5: Começando st_make_valid() em: cur
#
#
#
# 2021-12-08 10:35:37 - 5-5: Começando cálculo de área do pedaço em: cur
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 21,973 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 21,932 unique values and 0% NA
#
#
# 2021-12-08 10:35:39 - Finalizado: cur
#
#
# 2021-12-08 10:35:39 - Trabalhando na cidade: for
#
#
#
# 2021-12-08 10:35:40 - 1-5: Começando cálculo de área geral em grade_corrigida em: for
#
#
# mutate: new variable 'area_antes' (double) with 6,267 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 6,211 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,201 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 3,804 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 3,804 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x      56
#
#            > rows only in y  (    0)
#
#            > matched rows     6,211
#
#            >                 =======
#
#            > rows total       6,267
#
# mutate: new variable 'area_depois' (double) with 6,267 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and 1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:48 - 2-5: Começando cálculo de área geral em setor em : for
#
#
# mutate: new variable 'id_setor' (integer) with 3,043 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 3,043 unique values and 0% NA
#
#
# 2021-12-08 10:35:49 - 3-5: Começando st_intersection() grade_corrigida vs setor em: for
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:55 - 4-5: Começando st_make_valid() em: for
#
#
#
# 2021-12-08 10:35:58 - 5-5: Começando cálculo de área do pedaço em: for
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 20,080 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 20,055 unique values and 0% NA
#
#
# 2021-12-08 10:35:59 - Finalizado: for
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: goi
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: goi
#
#
# mutate: new variable 'area_antes' (double) with 8,379 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 8,377 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 649 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 2,744 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 2,744 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       3
#
#            > rows only in y  (    0)
#
#            > matched rows     8,377
#
#            >                 =======
#
#            > rows total       8,380
#
# mutate: new variable 'area_depois' (double) with 8,379 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:25 - 2-5: Começando cálculo de área geral em setor em : goi
#
#
# mutate: new variable 'id_setor' (integer) with 1,636 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,636 unique values and 0% NA
#
#
# 2021-12-08 10:35:25 - 3-5: Começando st_intersection() grade_corrigida vs setor em: goi
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:32 - 4-5: Começando st_make_valid() em: goi
#
#
#
# 2021-12-08 10:35:34 - 5-5: Começando cálculo de área do pedaço em: goi
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 17,496 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 17,503 unique values and 0% NA
#
#
# 2021-12-08 10:35:36 - Finalizado: goi
#
#
# 2021-12-08 10:35:36 - Trabalhando na cidade: mac
#
#
#
# 2021-12-08 10:35:36 - 1-5: Começando cálculo de área geral em grade_corrigida em: mac
#
#
# mutate: new variable 'area_antes' (double) with 3,055 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 3,047 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 911 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,803 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,803 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       8
#
#            > rows only in y  (    0)
#
#            > matched rows     3,047
#
#            >                 =======
#
#            > rows total       3,055
#
# mutate: new variable 'area_depois' (double) with 3,055 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:40 - 2-5: Começando cálculo de área geral em setor em : mac
#
#
# mutate: new variable 'id_setor' (integer) with 1,058 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,058 unique values and 0% NA
#
#
# 2021-12-08 10:35:40 - 3-5: Começando st_intersection() grade_corrigida vs setor em: mac
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:44 - 4-5: Começando st_make_valid() em: mac
#
#
#
# 2021-12-08 10:35:45 - 5-5: Começando cálculo de área do pedaço em: mac
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 8,560 unique values and 0% NA
#         new variable 'pop_homens' (double) with 8,545 unique values and 0% NA
#
#
# 2021-12-08 10:35:46 - Finalizado: mac
#
#
# 2021-12-08 10:35:46 - Trabalhando na cidade: man
#
#
#
# 2021-12-08 10:35:47 - 1-5: Começando cálculo de área geral em grade_corrigida em: man
#
#
# mutate: new variable 'area_antes' (double) with 6,772 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 6,772 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,043 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 3,077 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 3,077 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       0
#
#            > rows only in y  (    0)
#
#            > matched rows     6,772
#
#            >                 =======
#
#            > rows total       6,772
#
# mutate: new variable 'area_depois' (double) with 6,772 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with one unique value and 0% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:55 - 2-5: Começando cálculo de área geral em setor em : man
#
#
# mutate: new variable 'id_setor' (integer) with 2,455 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 2,455 unique values and 0% NA
#
#
# 2021-12-08 10:35:55 - 3-5: Começando st_intersection() grade_corrigida vs setor em: man
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:36:00 - 4-5: Começando st_make_valid() em: man
#
#
#
# 2021-12-08 10:36:02 - 5-5: Começando cálculo de área do pedaço em: man
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 17,334 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 17,372 unique values and 0% NA
#
#
# 2021-12-08 10:36:03 - Finalizado: man
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: nat
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: nat
#
#
# mutate: new variable 'area_antes' (double) with 2,734 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 2,734 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 771 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,834 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,834 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       1
#
#            > rows only in y  (    0)
#
#            > matched rows     2,734
#
#            >                 =======
#
#            > rows total       2,735
#
# mutate: new variable 'area_depois' (double) with 2,734 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:20 - 2-5: Começando cálculo de área geral em setor em : nat
#
#
# mutate: new variable 'id_setor' (integer) with 910 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 910 unique values and 0% NA
#
#
# 2021-12-08 10:35:20 - 3-5: Começando st_intersection() grade_corrigida vs setor em: nat
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:23 - 4-5: Começando st_make_valid() em: nat
#
#
#
# 2021-12-08 10:35:24 - 5-5: Começando cálculo de área do pedaço em: nat
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 7,765 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 7,756 unique values and 0% NA
#
#
# 2021-12-08 10:35:25 - Finalizado: nat
#
#
# 2021-12-08 10:35:25 - Trabalhando na cidade: rec
#
#
#
# 2021-12-08 10:35:25 - 1-5: Começando cálculo de área geral em grade_corrigida em: rec
#
#
# mutate: new variable 'area_antes' (double) with 3,675 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 3,661 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,118 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 2,397 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 2,397 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x      15
#
#            > rows only in y  (    0)
#
#            > matched rows     3,661
#
#            >                 =======
#
#            > rows total       3,676
#
# mutate: new variable 'area_depois' (double) with 3,675 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:30 - 2-5: Começando cálculo de área geral em setor em : rec
#
#
# mutate: new variable 'id_setor' (integer) with 1,854 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,854 unique values and 0% NA
#
#
# 2021-12-08 10:35:31 - 3-5: Começando st_intersection() grade_corrigida vs setor em: rec
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:35 - 4-5: Começando st_make_valid() em: rec
#
#
#
# 2021-12-08 10:35:36 - 5-5: Começando cálculo de área do pedaço em: rec
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 11,940 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 11,947 unique values and 0% NA
#
#
# 2021-12-08 10:35:37 - Finalizado: rec
#
#
# 2021-12-08 10:35:37 - Trabalhando na cidade: rio
#
#
#
# 2021-12-08 10:35:40 - 1-5: Começando cálculo de área geral em grade_corrigida em: rio
#
#
# mutate: new variable 'area_antes' (double) with 15,061 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 15,073 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,757 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 6,808 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 6,808 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x        5
#
#            > rows only in y  (     0)
#
#            > matched rows     15,073
#
#            >                 ========
#            > rows total       15,078
#
# mutate: new variable 'area_depois' (double) with 15,061 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:36:02 - 2-5: Começando cálculo de área geral em setor em : rio
#
#
# mutate: new variable 'id_setor' (integer) with 10,504 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 10,504 unique values and 0% NA
#
#
# 2021-12-08 10:36:03 - 3-5: Começando st_intersection() grade_corrigida vs setor em: rio
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:36:16 - 4-5: Começando st_make_valid() em: rio
#
#
#
# 2021-12-08 10:36:22 - 5-5: Começando cálculo de área do pedaço em: rio
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 58,755 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 58,756 unique values and 0% NA
#
#
# 2021-12-08 10:36:25 - Finalizado: rio
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: sal
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: sal
#
#
# mutate: new variable 'area_antes' (double) with 5,272 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 5,263 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,504 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 3,274 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 3,274 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       9
#
#            > rows only in y  (    0)
#
#            > matched rows     5,263
#
#            >                 =======
#
#            > rows total       5,272
#
# mutate: new variable 'area_depois' (double) with 5,272 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:26 - 2-5: Começando cálculo de área geral em setor em : sal
#
#
# mutate: new variable 'id_setor' (integer) with 3,592 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 3,592 unique values and 0% NA
#
#
# 2021-12-08 10:35:26 - 3-5: Começando st_intersection() grade_corrigida vs setor em: sal
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:33 - 4-5: Começando st_make_valid() em: sal
#
#
#
# 2021-12-08 10:35:36 - 5-5: Começando cálculo de área do pedaço em: sal
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 19,857 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 19,872 unique values and 0% NA
#
#
# 2021-12-08 10:35:37 - Finalizado: sal
#
#
# 2021-12-08 10:35:37 - Trabalhando na cidade: spo
#
#
#
# 2021-12-08 10:35:41 - 1-5: Começando cálculo de área geral em grade_corrigida em: spo
#
#
# mutate: new variable 'area_antes' (double) with 23,523 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 23,519 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 1,822 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 10,576 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 10,576 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       26
#
#            > rows only in y  (     0)
#
#            > matched rows     23,519
#
#            >                 ========
#
#            > rows total       23,545
#
# mutate: new variable 'area_depois' (double) with 23,523 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:36:13 - 2-5: Começando cálculo de área geral em setor em : spo
#
#
# mutate: new variable 'id_setor' (integer) with 18,953 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 18,953 unique values and 0% NA
#
#
# 2021-12-08 10:36:13 - 3-5: Começando st_intersection() grade_corrigida vs setor em: spo
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:36:34 - 4-5: Começando st_make_valid() em: spo
#
#
#
# 2021-12-08 10:36:43 - 5-5: Começando cálculo de área do pedaço em: spo
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 98,139 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 98,164 unique values and 0% NA
#
#
# 2021-12-08 10:36:49 - Finalizado: spo
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: tsa
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: tsa
#
#
# mutate: new variable 'area_antes' (double) with 4,522 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 4,521 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 656 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 2,064 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 2,064 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       1
#
#            > rows only in y  (    0)
#
#            > matched rows     4,521
#
#            >                 =======
#
#            > rows total       4,522
#
# mutate: new variable 'area_depois' (double) with 4,522 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:21 - 2-5: Começando cálculo de área geral em setor em : tsa
#
#
# mutate: new variable 'id_setor' (integer) with 1,079 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,079 unique values and 0% NA
#
#
# 2021-12-08 10:35:21 - 3-5: Começando st_intersection() grade_corrigida vs setor em: tsa
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:25 - 4-5: Começando st_make_valid() em: tsa
#
#
#
# 2021-12-08 10:35:26 - 5-5: Começando cálculo de área do pedaço em: tsa
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 10,190 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 10,190 unique values and 0% NA
#
#
# 2021-12-08 10:35:27 - Finalizado: tsa
#
#
# 2021-12-08 10:35:27 - Trabalhando na cidade: jpa
#
#
#
# 2021-12-08 10:35:28 - 1-5: Começando cálculo de área geral em grade_corrigida em: jpa
#
#
# mutate: new variable 'area_antes' (double) with 3,049 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 3,048 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 725 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,729 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,729 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       1
#
#            > rows only in y  (    0)
#
#            > matched rows     3,048
#
#            >                 =======
#
#            > rows total       3,049
#
# mutate: new variable 'area_depois' (double) with 3,049 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:31 - 2-5: Começando cálculo de área geral em setor em : jpa
#
#
# mutate: new variable 'id_setor' (integer) with 963 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 963 unique values and 0% NA
#
#
# 2021-12-08 10:35:31 - 3-5: Começando st_intersection() grade_corrigida vs setor em: jpa
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:34 - 4-5: Começando st_make_valid() em: jpa
#
#
#
# 2021-12-08 10:35:35 - 5-5: Começando cálculo de área do pedaço em: jpa
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 7,813 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 7,824 unique values and 0% NA
#
#
# 2021-12-08 10:35:36 - Finalizado: jpa
#
#
# 2021-12-08 10:35:36 - Trabalhando na cidade: ula
#
#
#
# 2021-12-08 10:35:36 - 1-5: Começando cálculo de área geral em grade_corrigida em: ula
#
#
# mutate: new variable 'area_antes' (double) with 4,345 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 4,345 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 517 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,655 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,655 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       0
#
#            > rows only in y  (    0)
#
#            > matched rows     4,345
#
#            >                 =======
#
#            > rows total       4,345
#
# mutate: new variable 'area_depois' (double) with 4,345 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with one unique value and 0% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:41 - 2-5: Começando cálculo de área geral em setor em : ula
#
#
# mutate: new variable 'id_setor' (integer) with 664 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 664 unique values and 0% NA
#
#
# 2021-12-08 10:35:41 - 3-5: Começando st_intersection() grade_corrigida vs setor em: ula
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:44 - 4-5: Começando st_make_valid() em: ula
#
#
#
# 2021-12-08 10:35:46 - 5-5: Começando cálculo de área do pedaço em: ula
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 7,886 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 7,967 unique values and 0% NA
#
#
# 2021-12-08 10:35:47 - Finalizado: ula
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: vta
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: vta
#
#
# mutate: new variable 'area_antes' (double) with 856 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 847 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 532 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 656 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 656 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x     9
#
#            > rows only in y  (  0)
#
#            > matched rows     847
#
#            >                 =====
#
#            > rows total       856
#
# mutate: new variable 'area_depois' (double) with 856 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and 1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:18 - 2-5: Começando cálculo de área geral em setor em : vta
#
#
# mutate: new variable 'id_setor' (integer) with 577 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 577 unique values and 0% NA
#
#
# 2021-12-08 10:35:18 - 3-5: Começando st_intersection() grade_corrigida vs setor em: vta
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:19 - 4-5: Começando st_make_valid() em: vta
#
#
#
# 2021-12-08 10:35:19 - 5-5: Começando cálculo de área do pedaço em: vta
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 3,074 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 3,070 unique values and 0% NA
#
#
# 2021-12-08 10:35:20 - Finalizado: vta
#
#
# 2021-12-08 10:35:20 - Trabalhando na cidade: oco
#
#
#
# 2021-12-08 10:35:20 - 1-5: Começando cálculo de área geral em grade_corrigida em: oco
#
#
# mutate: new variable 'area_antes' (double) with 1,390 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 1,386 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 780 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,098 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,098 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       4
#            > rows only in y  (    0)
#
#            > matched rows     1,386
#
#            >                 =======
#
#            > rows total       1,390
#
# mutate: new variable 'area_depois' (double) with 1,390 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:22 - 2-5: Começando cálculo de área geral em setor em : oco
#
#
# mutate: new variable 'id_setor' (integer) with 943 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 943 unique values and 0% NA
#
#
# 2021-12-08 10:35:22 - 3-5: Começando st_intersection() grade_corrigida vs setor em: oco
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:24 - 4-5: Começando st_make_valid() em: oco
#
#
#
# 2021-12-08 10:35:24 - 5-5: Começando cálculo de área do pedaço em: oco
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 5,264 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 5,262 unique values and 0% NA
#
#
# 2021-12-08 10:35:25 - Finalizado: oco
#
#
# 2021-12-08 10:35:16 - Trabalhando na cidade: sne
#
#
#
# 2021-12-08 10:35:17 - 1-5: Começando cálculo de área geral em grade_corrigida em: sne
#
#
# mutate: new variable 'area_antes' (double) with 1,981 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 1,972 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 796 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,399 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,399 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       9
#
#            > rows only in y  (    0)
#
#            > matched rows     1,972
#
#            >                 =======
#
#            > rows total       1,981
#
# mutate: new variable 'area_depois' (double) with 1,981 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:19 - 2-5: Começando cálculo de área geral em setor em : sne
#
#
# mutate: new variable 'id_setor' (integer) with 1,194 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,194 unique values and 0% NA
#
#
# 2021-12-08 10:35:19 - 3-5: Começando st_intersection() grade_corrigida vs setor em: sne
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:21 - 4-5: Começando st_make_valid() em: sne
#
#
#
# 2021-12-08 10:35:22 - 5-5: Começando cálculo de área do pedaço em: sne
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 7,008 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 7,012 unique values and 0% NA
#
#
# 2021-12-08 10:35:23 - Finalizado: sne
#
#
# 2021-12-08 10:35:23 - Trabalhando na cidade: sjc
#
#
#
# 2021-12-08 10:35:24 - 1-5: Começando cálculo de área geral em grade_corrigida em: sjc
#
#
# mutate: new variable 'area_antes' (double) with 4,390 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 4,391 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 649 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,428 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,428 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       0
#
#            > rows only in y  (    0)
#
#            > matched rows     4,391
#
#            >                 =======
#
#            > rows total       4,391
#
# mutate: new variable 'area_depois' (double) with 4,390 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with one unique value and 0% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:29 - 2-5: Começando cálculo de área geral em setor em : sjc
#
#
# mutate: new variable 'id_setor' (integer) with 1,074 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 1,074 unique values and 0% NA
#
#
# 2021-12-08 10:35:29 - 3-5: Começando st_intersection() grade_corrigida vs setor em: sjc
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:32 - 4-5: Começando st_make_valid() em: sjc
#
#
#
# 2021-12-08 10:35:34 - 5-5: Começando cálculo de área do pedaço em: sjc
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 9,612 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 9,642 unique values and 0% NA
#
#
# 2021-12-08 10:35:35 - Finalizado: sjc
#
#
# 2021-12-08 10:35:35 - Trabalhando na cidade: lda
#
#
#
# 2021-12-08 10:35:35 - 1-5: Começando cálculo de área geral em grade_corrigida em: lda
#
#
# mutate: new variable 'area_antes' (double) with 4,041 unique values and 0% NA
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
# group_by: one grouping variable (id_grade)
#
# summarise: now 4,039 rows and 5 columns, ungrouped
#
# mutate: new variable 'soma_pop_hm' (integer) with 538 unique values and 0% NA
#
#         new variable 'prop_homens' (double) with 1,488 unique values and 0% NA
#
#         new variable 'prop_mulheres' (double) with 1,488 unique values and 0% NA
#
# left_join: added 6 columns (pop_total, pop_homens, pop_mulheres, prop_homens, prop_mulheres, …)
#
#            > rows only in x       2
#
#            > rows only in y  (    0)
#
#            > matched rows     4,039
#
#            >                 =======
#
#            > rows total       4,041
#
# mutate: new variable 'area_depois' (double) with 4,041 unique values and 0% NA
#
# mutate: new variable 'prop' (double) with 2 unique values and <1% NA
#
# mutate: converted 'pop_total' from integer to double (0 new NA)
#
#         converted 'pop_homens' from integer to double (0 new NA)
#
#         converted 'pop_mulheres' from integer to double (0 new NA)
#
# rename: renamed one variable (area_grade)
#
#
# 2021-12-08 10:35:39 - 2-5: Começando cálculo de área geral em setor em : lda
#
#
# mutate: new variable 'id_setor' (integer) with 717 unique values and 0% NA
#
# mutate: new variable 'area_setor' (double) with 717 unique values and 0% NA
#
#
# 2021-12-08 10:35:39 - 3-5: Começando st_intersection() grade_corrigida vs setor em: lda
#
#
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
#
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”
#
# 2021-12-08 10:35:42 - 4-5: Começando st_make_valid() em: lda
# 2021-12-08 10:35:44 - 5-5: Começando cálculo de área do pedaço em: lda
#
#
# group_by: one grouping variable (id_setor)
#
# ungroup: no grouping variables
#
# mutate: new variable 'pop_mulheres' (double) with 7,586 unique values and 0% NA
#
#         new variable 'pop_homens' (double) with 7,603 unique values and 0% NA
#
#
# 2021-12-08 10:35:45 - Finalizado: lda
